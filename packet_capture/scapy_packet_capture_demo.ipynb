# %%
from scapy.all import *

# %% [markdown]
# Display available network interfaces
# conf.ifaces: This command lists all available network interfaces on the system, which can help to identify the correct interface to use for packet capturing.

# %%
conf.ifaces
# Out:
# Source   Index  Name                                       MAC                 IPv4            IPv6
# libpcap  1      Software Loopback Interface 1              00:00:00:00:00:00   127.0.0.1       ::1
# libpcap  11     TAP-Windows Adapter V9                     00:ff:78:e8:8b:85   169.254.23.92   fe80::f398:eee0:dc26:1aaa
# libpcap  12     WAN Miniport (Network Monitor)
# libpcap  13     WAN Miniport (IP)
# libpcap  14     Bluetooth Device (Personal Area Network)   Microsoft:d7:28:ff  169.254.49.59   fe80::76e9:4b0a:ca98:40d3
# libpcap  17     Intel(R) Wi-Fi 6E AX210 160MHz             Microsoft:d7:28:fb  10.118.127.151  fe80::3872:af95:3c02:f2c2
# libpcap  18     Wintun Userspace Tunnel                                        169.254.111.20  fe80::e405:8850:fb38:c748
# libpcap  19     WAN Miniport (IPv6)
# libpcap  2      Microsoft Wi-Fi Direct Virtual Adapter     Microsoft:d7:28:fc  169.254.248.90  fe80::b099:8d38:5940:d10f
# ...

# %% [markdown]
# Capture one packet from the loopback interface with a filter for localhost (127.0.0.1)

# %%
packets = sniff(count = 1, filter="host 127.0.0.1", iface = "Software Loopback Interface 1" ,timeout = 10)
packets.summary()
# Out:
# Loopback / IP / TCP 127.0.0.1:55797 > 127.0.0.1:49152 PA / Raw

# %% [markdown]
# Packet capturing during 5 seconds  with a filter for localhost (127.0.0.1),
#
# 1. Check if the packet has an IP layer
# 2. Print the source and destination IPs and ports, along with the packet size

# %%
# Define the filter parameter
target_ip = "127.0.0.1"  # Change to the target IP address
#target_port = 60285 

# Define a function to process each packet
def packet_callback(packet):
    # Check if the packet has an IP layer
    if IP in packet:
        ip_layer = packet[IP]
        # Check if the source or destination IP matches the target IP
        if ip_layer.src == target_ip or ip_layer.dst == target_ip:
            
            print(f"Captured packet: {ip_layer.src}:{packet.sport} -> {ip_layer.dst}:{packet.dport}, Size: {len(packet)} bytes")

# Start sniffing the packets

#sniff(filter=f"ip and (tcp port {target_port} or udp port {target_port})", prn=packet_callback, store=0, iface = "Software Loopback Interface 1" ,timeout = 5)

sniff(filter=f"ip host {target_ip}", prn=packet_callback, store=0, iface = "Software Loopback Interface 1" ,timeout = 5)
# Out:
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 106 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 44 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 45 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 44 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 134 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 44 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 45 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 44 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 102 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 44 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 45 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 44 bytes
# Captured packet: 127.0.0.1:49152 -> 127.0.0.1:55797, Size: 407 bytes
# Captured packet: 127.0.0.1:55797 -> 127.0.0.1:49152, Size: 44 bytes
# ...
